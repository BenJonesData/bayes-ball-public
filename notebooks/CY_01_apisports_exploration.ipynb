# %% [markdown]
# # API Sports Connection

# %% [markdown]
# Notebook to read in different types of football data sources from the football api to understand date and stastical limitations.

# %%
import pandas as pd
import requests
import json
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", 1000)  # Show all columns

# %%
europe_league_ids = [2,3,848,527]
english_league_ids = [39,40,41,42,43,45,48,49,50,51,529,984,985, 1156]
all_leagues = europe_league_ids + english_league_ids
seasons = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025]

# %%
API_KEY = "ad4b0c261d9bb7ea250891693538fa3b"
HEADERS = {"x-apisports-key": API_KEY}

# %% [markdown]
# ## Fixtures

# %% [markdown]
# Fixtures data is great. Appears to have all leagues and seasons back to 2010. Will easily be able to use this for training and generating features.

# %%
def get_league_fixtures(league, year):
    URL = "https://v3.football.api-sports.io/fixtures"

    params = {
        "league": league, 
        "season": year  
    }

    response = requests.get(url, headers=HEADERS, params=params)
    data = response.json()
    fixtures = data.get("response", [])
    match_list = []
    for match in fixtures:
        match_list.append({
            "fixture_id": match['fixture']['id'],
            "match_date": match['fixture']['date'],
            "league": match['league']['name'],
            "referee": match['fixture']['referee'],
            "season": match['league']['season'],
            "timezone": match['fixture']['timezone'],
            "ground": match['fixture']['venue']['name'],
            "city": match['fixture']['venue']['city'],
            "home_team": match['teams']['home']['name'],
            "away_team": match['teams']['away']['name'],
            "round": match['league']['round'],
            "status": match['fixture']['status']['short'],
            "home_win": match['teams']['home']['winner'],
            "away_win": match['teams']['away']['winner'],
            "home_score_90": match['goals']['home'],
            "away_score_90": match['goals']['away'],
            "home_score_45": match['score']['halftime']['home'],
            "away_score_45": match['score']['halftime']['away'],
            "home_score_et": match['score']['extratime']['home'],
            "away_score_et": match['score']['extratime']['away'],
            "home_score_pen": match['score']['penalty']['home'],
            "away_score_pen": match['score']['penalty']['away'],
            "venue_id": match['fixture']['venue']['id'],
            "league_id": match['league']['id'],
            "home_team_id": match['teams']['home']['id'],
            "away_team_id": match['teams']['away']['id'],
        })

    df = pd.DataFrame(match_list)
    return df

# %%
all_fixtures_df = pd.DataFrame()
for league_id in english_league_ids + europe_league_ids:
    for season in seasons:
        df = get_league_fixtures(league_id, season)

        all_fixtures_df = pd.concat([all_fixtures_df, df], ignore_index=True)

all_fixtures_df.to_csv("../data/football_data/apisports_data.csv")

# %%
all_fixtures_df.groupby(['league'])['match_date'].max()
# Out:
# league
# Championship                     2025-05-03T14:00:00+00:00
# FA Cup                           2025-03-01T15:00:00+00:00
# League Cup                       2025-02-06T20:00:00+00:00
# League One                       2025-05-03T14:00:00+00:00
# League Two                       2025-05-03T14:00:00+00:00
# Premier League                   2025-05-25T15:00:00+00:00
# Super Cup                        2025-01-25T21:00:00+00:00
# UEFA Champions League            2025-02-19T20:00:00+00:00
# UEFA Europa Conference League    2025-02-20T20:00:00+00:00
# UEFA Europa League               2025-02-20T20:00:00+00:00
# Name: match_date, dtype: object

# %% [markdown]
# ## Injuries

# %%
def get_injuries_for_team(team_id, league_id, season):
    url = f"https://v3.football.api-sports.io/injuries?season={season}&league={league_id}&team={team_id}"
    response = requests.get(url, headers=HEADERS)
    data = response.json()
    
    return data['response']

def collect_injury_data(team_ids, league_id, season):
    injury_data = []

    for team_id in team_ids:
        injuries = get_injuries_for_team(team_id, league_id, season)
        
        for injury in injuries:
            player = injury['player']['name']
            player_id = injury['player']['id']
            game_type = injury['player']['type']
            injury_type = injury['player']['reason']
            date = injury['fixture']['date']
            fixture_id = injury['fixture']['id']
            
            injury_data.append({
                'player': player,
                'game_type': game_type,
                'injury_type': injury_type,
                'date': date,
                'season': season,
                'fixture_id': fixture_id,
                'player_id': player_id,
                'team_id': team_id,
            })

    return pd.DataFrame(injury_data)

# %%
LEAGUE_ID = 39  # Example: Premier League (Check API-Football docs for other league IDs)
SEASON = 2023  # Specify the season

# API Endpoint
url = "https://v3.football.api-sports.io/injuries"


# Query parameters
params = {
    "league": LEAGUE_ID,
    "season": SEASON
}

# Make the request
response = requests.get(url, headers=HEADERS, params=params)
    data = response.json()
    injuries = data.get("response", [])
else:
    print("Error:", response.json())

# %%
df = pd.json_normalize(injuries)
df.columns = [col.replace('.', '_') for col in df.columns]
df
# Out:
#       player_id    player_name  \
# 0         18957     M. Obafemi
# 1          1452      M. Elneny
# 2           643  Gabriel Jesus
# 3        138835     F. Balogun
# 4          1427  A. S. Lokonga
# ...         ...            ...
# 3848       2413    Richarlison
# 3849      19032   R. Sessegnon
# 3850        697     M. Solomon
# 3851     204039      D. Udogie
# 3852       1166      T. Werner
#
#                                            player_photo      player_type  \
# 0     https://media.api-sports.io/football/players/1...  Missing Fixture
# 1     https://media.api-sports.io/football/players/1...  Missing Fixture
# 2     https://media.api-sports.io/football/players/6...  Missing Fixture
# 3     https://media.api-sports.io/football/players/1...     Questionable
# 4     https://media.api-sports.io/football/players/1...     Questionable
# ...                                                 ...              ...
# 3848  https://media.api-sports.io/football/players/2...  Missing Fixture
# 3849  https://media.api-sports.io/football/players/1...  Missing Fixture
# 3850  https://media.api-sports.io/football/players/6...  Missing Fixture
# 3851  https://media.api-sports.io/football/players/2...  Missing Fixture
# 3852  https://media.api-sports.io/football/players/1...  Missing Fixture
#
#       player_reason  team_id  team_name  \
# 0      Thigh Injury       44    Burnley
# 1             Knock       42    Arsenal
# 2       Knee Injury       42    Arsenal
# 3      Ankle Injury       42    Arsenal
# 4     Muscle Injury       42    Arsenal
# ...             ...      ...        ...
# 3848    Calf Injury       47  Tottenham
# 3849   Thigh Injury       47  Tottenham
# 3850    Knee Injury       47  Tottenham
# 3851   Thigh Injury       47  Tottenham
# 3852   Thigh Injury       47  Tottenham
#
#                                               team_logo  fixture_id  \
# 0     https://media.api-sports.io/football/teams/44.png     1035037
# 1     https://media.api-sports.io/football/teams/42.png     1035038
# 2     https://media.api-sports.io/football/teams/42.png     1035038
# 3     https://media.api-sports.io/football/teams/42.png     1035038
# 4     https://media.api-sports.io/football/teams/42.png     1035038
# ...                                                 ...         ...
# 3848  https://media.api-sports.io/football/teams/47.png     1035553
# 3849  https://media.api-sports.io/football/teams/47.png     1035553
# 3850  https://media.api-sports.io/football/teams/47.png     1035553
# 3851  https://media.api-sports.io/football/teams/47.png     1035553
# 3852  https://media.api-sports.io/football/teams/47.png     1035553
#
#      fixture_timezone               fixture_date  fixture_timestamp  \
# 0                 UTC  2023-08-11T19:00:00+00:00         1691780400
# 1                 UTC  2023-08-12T11:30:00+00:00         1691839800
# 2                 UTC  2023-08-12T11:30:00+00:00         1691839800
# 3                 UTC  2023-08-12T11:30:00+00:00         1691839800
# 4                 UTC  2023-08-12T11:30:00+00:00         1691839800
# ...               ...                        ...                ...
# 3848              UTC  2024-05-19T15:00:00+00:00         1716130800
# 3849              UTC  2024-05-19T15:00:00+00:00         1716130800
# 3850              UTC  2024-05-19T15:00:00+00:00         1716130800
# 3851              UTC  2024-05-19T15:00:00+00:00         1716130800
# 3852              UTC  2024-05-19T15:00:00+00:00         1716130800
#
#       league_id  league_season     league_name league_country  \
# 0            39           2023  Premier League        England
# 1            39           2023  Premier League        England
# 2            39           2023  Premier League        England
# 3            39           2023  Premier League        England
# 4            39           2023  Premier League        England
# ...         ...            ...             ...            ...
# 3848         39           2023  Premier League        England
# 3849         39           2023  Premier League        England
# 3850         39           2023  Premier League        England
# 3851         39           2023  Premier League        England
# 3852         39           2023  Premier League        England
#
#                                             league_logo  \
# 0     https://media.api-sports.io/football/leagues/3...
# 1     https://media.api-sports.io/football/leagues/3...
# 2     https://media.api-sports.io/football/leagues/3...
# 3     https://media.api-sports.io/football/leagues/3...
# 4     https://media.api-sports.io/football/leagues/3...
# ...                                                 ...
# 3848  https://media.api-sports.io/football/leagues/3...
# 3849  https://media.api-sports.io/football/leagues/3...
# 3850  https://media.api-sports.io/football/leagues/3...
# 3851  https://media.api-sports.io/football/leagues/3...
# 3852  https://media.api-sports.io/football/leagues/3...
#
#                                        league_flag
# 0     https://media.api-sports.io/flags/gb-eng.svg
# 1     https://media.api-sports.io/flags/gb-eng.svg
# 2     https://media.api-sports.io/flags/gb-eng.svg
# 3     https://media.api-sports.io/flags/gb-eng.svg
# 4     https://media.api-sports.io/flags/gb-eng.svg
# ...                                            ...
# 3848  https://media.api-sports.io/flags/gb-eng.svg
# 3849  https://media.api-sports.io/flags/gb-eng.svg
# 3850  https://media.api-sports.io/flags/gb-eng.svg
# 3851  https://media.api-sports.io/flags/gb-eng.svg
# 3852  https://media.api-sports.io/flags/gb-eng.svg
#
# [3853 rows x 18 columns]

# %%
injuries = get_injuries_for_team(team_ids[0], league_id, 2024)

# %%
injuries = collect_injury_data(team_ids, english_league_ids[0], seasons[0])

# %%
injuries[injuries['player'] == 'M. Rashford']
# Out:
#           player        game_type      injury_type                       date  \
# 1    M. Rashford  Missing Fixture  Shoulder Injury  2021-08-22T13:00:00+00:00
# 8    M. Rashford  Missing Fixture  Shoulder Injury  2021-08-29T15:30:00+00:00
# 13   M. Rashford  Missing Fixture  Shoulder Injury  2021-09-11T14:00:00+00:00
# 20   M. Rashford  Missing Fixture  Shoulder Injury  2021-09-19T13:00:00+00:00
# 23   M. Rashford  Missing Fixture  Shoulder Injury  2021-09-25T11:30:00+00:00
# 147  M. Rashford  Missing Fixture          Illness  2022-05-07T16:30:00+00:00
# 154  M. Rashford     Questionable          Illness  2022-05-22T15:00:00+00:00
#
#      season  fixture_id  player_id  team_id
# 1      2021      710573        909       33
# 8      2021      710585        909       33
# 13     2021      710593        909       33
# 20     2021      710604        909       33
# 23     2021      710613        909       33
# 147    2021      710908        909       33
# 154    2021      710931        909       33

# %% [markdown]
# ## Coaches

# %%
def get_managers(team_id):
    url = f"https://v3.football.api-sports.io/coachs?team={team_id}"
    response = requests.get(url, headers=HEADERS).json()
    
    managers = []
    for coach in response['response']:
        managers.append({
            'Team': coach['team']['name'] if coach.get('team') else 'Unknown',
            'Manager': coach['name'],
            'Nationality': coach['nationality'],
            'Start Date': coach.get('start'),
            'End Date': coach.get('end', 'Present')
        })
    return managers

# %%
get_managers(33)
# Out:
# [{'Team': 'Manchester United',
#   'Manager': 'E. ten Hag',
#   'Nationality': 'Netherlands',
#   'Start Date': None,
#   'End Date': 'Present'},
#  {'Team': 'Manchester United',
#   'Manager': 'Ruben Amorim',
#   'Nationality': 'Portugal',
#   'Start Date': None,
#   'End Date': 'Present'}]

# %% [markdown]
# ## Statistics

# %%
    BASE_URL = "https://v3.football.api-sports.io"

    url = f"{BASE_URL}/fixtures/statistics?fixture={868324}"
    response = requests.get(url, headers=HEADERS)
    data = response.json()
    fixtures = data.get("response", [])
    df = pd.json_normalize(fixtures)
    df.columns = [col.replace('.', '_') for col in df.columns]
    df = df.explode("statistics")
    df_stats = pd.json_normalize(df["statistics"])
    df = df.drop(columns=["statistics"]).reset_index(drop=True)
    df = pd.concat([df, df_stats], axis=1)
    df = df.pivot(index=["team_id", "team_name"], columns="type", values="value").reset_index()

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df
# Out:
# type  team_id          team_name ball_possession blocked_shots corner_kicks  \
# 0          33  Manchester United             53%             6            5
# 1          36             Fulham             47%             1            4
#
# type fouls goalkeeper_saves offsides passes_% passes_accurate red_cards  \
# 0       14                2        1      84%             415      None
# 1       10                6        1      84%             358      None
#
# type shots_insidebox shots_off_goal shots_on_goal shots_outsidebox  \
# 0                 12              7             8                9
# 1                  6              6             3                4
#
# type total_shots total_passes yellow_cards expected_goals
# 0             21          493            1           2.89
# 1             10          426            2           1.80

# %%
BASE_URL = "https://v3.football.api-sports.io"

url = f"{BASE_URL}/fixtures/statistics?fixture={868324}"
response = requests.get(url, headers=HEADERS)
data = response.json()

fixtures = data.get("response", [])
df = pd.json_normalize(fixtures)
df.columns = [col.replace('.', '_') for col in df.columns]
df = df.explode("statistics")
df_stats = pd.json_normalize(df["statistics"])
df = df.drop(columns=["statistics"]).reset_index(drop=True)
df = pd.concat([df, df_stats], axis=1)
df = df.pivot(index=["team_id", "team_name"], columns="type", values="value").reset_index()
df

# if response.status_code == 200:
#     stats = response.json()["response"]
#    print({team["team"]["name"]: {stat["type"]: stat["value"] for stat in team["statistics"]} for team in stats})
# Out:
# type  team_id          team_name Ball Possession Blocked Shots Corner Kicks  \
# 0          33  Manchester United             53%             6            5
# 1          36             Fulham             47%             1            4
#
# type Fouls Goalkeeper Saves Offsides Passes % Passes accurate Red Cards  \
# 0       14                2        1      84%             415      None
# 1       10                6        1      84%             358      None
#
# type Shots insidebox Shots off Goal Shots on Goal Shots outsidebox  \
# 0                 12              7             8                9
# 1                  6              6             3                4
#
# type Total Shots Total passes Yellow Cards expected_goals
# 0             21          493            1           2.89
# 1             10          426            2           1.80

# %%
fixtures = data.get("response", [])
df = pd.json_normalize(fixtures)
df.columns = [col.replace('.', '_') for col in df.columns]
df
# Out:
#                                           statistics  team_id  \
# 0  [{'type': 'Shots on Goal', 'value': 8}, {'type...       33
# 1  [{'type': 'Shots on Goal', 'value': 3}, {'type...       36
#
#            team_name                                          team_logo
# 0  Manchester United  https://media.api-sports.io/football/teams/33.png
# 1             Fulham  https://media.api-sports.io/football/teams/36.png

# %%
data = response.json()
stats = data.get("response", [])
stats = pd.json_normalize(stats)

# %%
stats
# Out:
#                                           statistics  team.id  \
# 0  [{'type': 'Shots on Goal', 'value': 8}, {'type...       33
# 1  [{'type': 'Shots on Goal', 'value': 3}, {'type...       36
#
#            team.name                                          team.logo
# 0  Manchester United  https://media.api-sports.io/football/teams/33.png
# 1             Fulham  https://media.api-sports.io/football/teams/36.png

# %% [markdown]
# ## Predictions

# %%
url = "https://v3.football.api-sports.io/predictions"
params = {
    "fixture": 157391,
}

response = requests.get(url, headers=HEADERS, params=params)

data = response.json()
predictions = data.get("response", [])

# Convert to DataFrame using json_normalize
df = pd.json_normalize(predictions)
df.columns = [col.replace('.', '_') for col in df.columns]

# %%
df['h2h']
# Out:
# 0    [{'fixture': {'id': 157060, 'referee': 'Kevin ...
# Name: h2h, dtype: object
